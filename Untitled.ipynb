# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Failure_Prediction.csv")

df.head()
# Out:
#     node_id  cpu_usage_percent  ram_usage_percent  disk_usage_percent  \
# 0  Node-001               44.2               37.6                39.0
# 1  Node-002               20.2               20.2                38.9
# 2  Node-003               62.8               43.4                44.7
# 3  Node-004               54.7               51.8                48.3
# 4  Node-005               91.2               84.2                58.0
#
#    network_usage_percent  active_jobs  idle_time_minutes  \
# 0                   55.0            6                268
# 1                   18.8            1                320
# 2                   55.3           10                230
# 3                   61.1            1                317
# 4                   62.9            7                 68
#
#    power_consumption_watts  temperature_celsius failure_risk
# 0                      264                 43.3          Low
# 1                      120                 35.7          Low
# ...

# %%
df.shape
# Out:
# (25000, 10)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   node_id                  25000 non-null  str
#  1   cpu_usage_percent        25000 non-null  float64
#  2   ram_usage_percent        25000 non-null  float64
#  3   disk_usage_percent       25000 non-null  float64
#  4   network_usage_percent    25000 non-null  float64
#  5   active_jobs              25000 non-null  int64
#  6   idle_time_minutes        25000 non-null  int64
#  7   power_consumption_watts  25000 non-null  int64
#  8   temperature_celsius      25000 non-null  float64
#  9   failure_risk             25000 non-null  str
# dtypes: float64(5), int64(3), str(2)
# memory usage: 2.2 MB

# %%
df.isnull().sum()
# Out:
# node_id                    0
# cpu_usage_percent          0
# ram_usage_percent          0
# disk_usage_percent         0
# network_usage_percent      0
# active_jobs                0
# idle_time_minutes          0
# power_consumption_watts    0
# temperature_celsius        0
# failure_risk               0
# dtype: int64

# %%
df["failure_risk"].value_counts()
# Out:
# failure_risk
# Low       12707
# Medium     9865
# High       2428
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# node_id                    0
# cpu_usage_percent          0
# ram_usage_percent          0
# disk_usage_percent         0
# network_usage_percent      0
# active_jobs                0
# idle_time_minutes          0
# power_consumption_watts    0
# temperature_celsius        0
# failure_risk               0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# node_id                    0
# cpu_usage_percent          0
# ram_usage_percent          0
# disk_usage_percent         0
# network_usage_percent      0
# active_jobs                0
# idle_time_minutes          0
# power_consumption_watts    0
# temperature_celsius        0
# failure_risk               0
# dtype: int64

# %%
df["failure_risk"].unique()
# Out:
# <ArrowStringArray>
# ['Low', 'Medium', 'High']
# Length: 3, dtype: str

# %%
plt.figure(figsize=(7,5))

sns.countplot(x="failure_risk", data=df)

plt.title("Failure Risk Distribution")
plt.xlabel("Failure Risk")
plt.ylabel("Number of Systems")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x="failure_risk",
    y="cpu_usage_percent",
    data=df
)

plt.title("CPU Usage vs Failure Risk")
plt.xlabel("Failure Risk")
plt.ylabel("CPU Usage (%)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x="failure_risk",
    y="temperature_celsius",
    data=df
)

plt.title("Temperature vs Failure Risk")
plt.xlabel("Failure Risk")
plt.ylabel("Temperature (°C)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x="failure_risk",
    y="ram_usage_percent",
    data=df
)

plt.title("RAM Usage vs Failure Risk")
plt.xlabel("Failure Risk")
plt.ylabel("RAM Usage (%)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x="failure_risk",
    y="disk_usage_percent",
    data=df
)

plt.title("Disk Usage vs Failure Risk")
plt.xlabel("Failure Risk")
plt.ylabel("Disk Usage (%)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x="failure_risk",
    y="network_usage_percent",
    data=df
)

plt.title("Network Usage vs Failure Risk")
plt.xlabel("Failure Risk")
plt.ylabel("Network Usage (%)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x="failure_risk",
    y="active_jobs",
    data=df
)

plt.title("Active Jobs vs Failure Risk")
plt.xlabel("Failure Risk")
plt.ylabel("Active Jobs")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x="failure_risk",
    y="power_consumption_watts",
    data=df
)

plt.title("Power Consumption vs Failure Risk")
plt.xlabel("Failure Risk")
plt.ylabel("Power (Watts)")

plt.show()

# %%
df_corr = df.copy()

df_corr["failure_risk"] = df_corr["failure_risk"].map({
    "Low": 0,
    "Medium": 1,
    "High": 2
})

# %%
plt.figure(figsize=(12,8))

sns.heatmap(
    df_corr.drop("node_id", axis=1).corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")

plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

X = df.drop(["node_id", "failure_risk"], axis=1)

encoder = LabelEncoder()
y = encoder.fit_transform(df["failure_risk"])

rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf.fit(X, y)
# Out:
# RandomForestClassifier(random_state=42)

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

print(importance)
# Out:
#                    Feature  Importance
# 0        cpu_usage_percent    0.313507
# 1        ram_usage_percent    0.181320
# 6  power_consumption_watts    0.174780
# 7      temperature_celsius    0.144555
# 5        idle_time_minutes    0.076119
# 3    network_usage_percent    0.042663
# 2       disk_usage_percent    0.037483
# 4              active_jobs    0.029573

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    x="Importance",
    y="Feature",
    data=importance
)

plt.title("Feature Importance")

plt.show()

# %%
X = df.drop(["node_id", "failure_risk"], axis=1)

y = df["failure_risk"]

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

y_encoded = encoder.fit_transform(y)

print(encoder.classes_)
# Out:
# ['High' 'Low' 'Medium']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y_encoded,
    test_size=0.20,
    random_state=42,
    stratify=y_encoded
)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# Training data: (20000, 8)
# Testing data: (5000, 8)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

lr_model = Pipeline([
    ("scaler", StandardScaler()),
    ("model", LogisticRegression(max_iter=1000))
])

lr_model.fit(X_train, y_train)

lr_pred = lr_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

lr_accuracy = accuracy_score(y_test, lr_pred)

print("Logistic Regression Accuracy:", lr_accuracy)
# Out:
# Logistic Regression Accuracy: 0.9952

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(
    random_state=42
)

dt_model.fit(X_train, y_train)

dt_pred = dt_model.predict(X_test)

dt_accuracy = accuracy_score(y_test, dt_pred)

print("Decision Tree Accuracy:", dt_accuracy)
# Out:
# Decision Tree Accuracy: 0.96

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=200,
    random_state=42,
    class_weight="balanced"
)

rf_model.fit(X_train, y_train)

rf_pred = rf_model.predict(X_test)

rf_accuracy = accuracy_score(y_test, rf_pred)

print("Random Forest Accuracy:", rf_accuracy)
# Out:
# Random Forest Accuracy: 0.9742

# %%
print("Model Performance")
print("-------------------------")
print("Logistic Regression :", lr_accuracy)
print("Decision Tree       :", dt_accuracy)
print("Random Forest       :", rf_accuracy)
# Out:
# Model Performance
# -------------------------
# Logistic Regression : 0.9952
# Decision Tree       : 0.96
# Random Forest       : 0.9742

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_test,
    rf_pred,
    target_names=encoder.classes_
))
# Out:
#               precision    recall  f1-score   support
#
#         High       0.94      0.97      0.96       486
#          Low       0.99      0.98      0.98      2541
#       Medium       0.97      0.97      0.97      1973
#
#     accuracy                           0.97      5000
#    macro avg       0.97      0.97      0.97      5000
# weighted avg       0.97      0.97      0.97      5000

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_test,
    rf_pred,
    target_names=encoder.classes_
))
# Out:
#               precision    recall  f1-score   support
#
#         High       0.94      0.97      0.96       486
#          Low       0.99      0.98      0.98      2541
#       Medium       0.97      0.97      0.97      1973
#
#     accuracy                           0.97      5000
#    macro avg       0.97      0.97      0.97      5000
# weighted avg       0.97      0.97      0.97      5000

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, rf_pred)

plt.figure(figsize=(7, 5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    xticklabels=encoder.classes_,
    yticklabels=encoder.classes_
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Random Forest Confusion Matrix")

plt.show()

# %%
import joblib

joblib.dump(rf_model, "failure_prediction_model.pkl")
joblib.dump(encoder, "failure_risk_encoder.pkl")
# Out:
# ['failure_risk_encoder.pkl']

# %%
import joblib

joblib.dump(rf_model, "failure_prediction_model.pkl")
joblib.dump(encoder, "failure_risk_encoder.pkl")

print("Model saved successfully!")
# Out:
# Model saved successfully!
